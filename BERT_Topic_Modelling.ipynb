# %% [markdown]
# # **BERTopic - Tutorial**

# %%
# !pip install bertopic[visualization] --quiet
# Out:
#      |████████████████████████████████| 90 kB 4.3 MB/s
# WARNING: bertopic 0.12.0 does not provide the extra 'visualization'
#      |████████████████████████████████| 5.2 MB 28.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 85 kB 5.4 MB/s
#      |████████████████████████████████| 636 kB 58.8 MB/s
#      |████████████████████████████████| 88 kB 7.9 MB/s
#      |████████████████████████████████| 4.9 MB 53.3 MB/s
#      |████████████████████████████████| 1.3 MB 56.3 MB/s
#      |████████████████████████████████| 163 kB 64.6 MB/s
#      |████████████████████████████████| 6.6 MB 48.6 MB/s
#      |████████████████████████████████| 1.1 MB 59.9 MB/s
#   Building wheel for hdbscan (PEP 517) ... done
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # **Imports**

# %%
import numpy as np
import pandas as pd
import json
from copy import deepcopy
from bertopic import BERTopic
import io
import pandas as pd
from google.colab import files
from textblob import TextBlob 
from textblob import Word
import string

import json

# %%
df = pd.read_json('/content/database.json')

docs = list(df.loc[:, "describe_sound"].values)

def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct).lower()
    return words_wo_punct

docs = [remove_punctuation(item) for item in docs]  
docs[:5]
# Out:
# ['a rumbling pulsating bass noise quite loud this time',
#  'low rumbling sound',
#  'constant metallic like a fan or idling truck  hum',
#  'pulsating low hum',
#  'low droning like a large engine idling some time you can feel the vibration from it']

# %% [markdown]
# # **Creating Topics**
# # We can then extract most frequent topics:

# %%
model = BERTopic(language="english")
topics, probs = model.fit_transform(docs)
model.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1   1035
# 1        0    122
# 2        1    108
# 3        2     96
# 4        3     89
# ..     ...    ...
# 203    202     11
# 204    203     11
# 205    204     11
# 206    205     10
# 207    206     10
#
# [208 rows x 2 columns]

# %% [markdown]
# # Get Individual Topics

# %%
#model.get_topic(0)
#model.get_topic(2)
model.get_topic(14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbefe07f3e48> in <module>
#       1 #model.get_topic(0)
#       2 #model.get_topic(2)
# ----> 3 model.get_topic(14)
#
# NameError: name 'model' is not defined

# %% [markdown]
# # **Visualize Topics**

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="45dda2f2-c209-4937-98c4-9a0a4077a496" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45dda2f2-c209-4937-98c4-9a0a4077a496")) {                    Plotly.newPlot(                        "45dda2f2-c209-4937-98c4-9a0a4077a496",                        [{"customdata":[[0,"frequency | hum | indicates | low | 1020",122],[1,"humming | night | sensing | he | im",108],[2,"night | at | sleep | sleeping | wakes",96],[3,"outside | sewer | hear | inside | house",89],[4,"roaring | humm | hum | humvibration | freaking",80],[5,"pulsing | vroom | per | pulse | tone",74],[6,"freq | boom | sound | varying | directions",70],[7,"rumbling | wooowoowoowooowoowoo | rumblingpulsating | genorator | squealing",67],[8,"vibrating | vibrational | vibration | loud | vibratingpulsating",60],[9,"buzzing | buzz | buzzinghumming | buzzingringingvibration | container",59],[10,"engine | an | hum | liie | running",59],[11,"rumbling | source | few | frequented | model",58],[12,"drone | mask | pitch | continuous | really",57],[13,"drone | giant | bottle | blowing | dronehum",55],[14,"50 | continual | hz | alternating | constant",54],[15,"constant | cocistent | httpswwwyoutubecomwatchvhpat8bixgjk | video | apruptly",53],[16,"generator | pith | standby | range | quietens",51],[17,"resonance | frequency | him | change | alternating",50],[18,"wie | brummen | ein | der | ist",49],[19,"horn | mwom | pitch | humrumbling | pitched",46],[20,"street | truck | road | semi | idling",45],[21,"diesel | distance | meters | large | away",44],[22,"humming | noise | higherlower | distinctive | stayed",44],[23,"diesel | sounds | motorcycle | happening | shore",42],[24,"truck | idling | street | closeness | revolving",42],[25,"vibrating | vibration | humn | vibrationoscillation | vibratingpulsingrumbling",42],[26,"deep | humming | prayer | eerie | orig",41],[27,"duh | bass | annoying | 2am | playing",41],[28,"night | louder | household | more | at",41],[29,"rumble | planes | seam | super | sky",41],[30,"bus | picking | passenger | parking | truck",40],[31,"humming | trucks | appliance | craft | truck",40],[32,"pulsating | 42hz | registering | slow | permeates",40],[33,"vibration | partly | purring | cat | myriad",39],[34,"diesel | slight | blocks | tickover | throttling",39],[35,"como | un | de | la | en",39],[36,"washing | spin | phone | subterranean | equipment",39],[37,"noise | irregularities | crickets | hissinghumming | 7778hz",38],[38,"humming | frequency | frequecy | location | hummingvibration",38],[39,"rumbling | drums | well | ears | burn",38],[40,"plane | above | tone | permeates | propeller",38],[41,"daytime | night | can | it | hear",37],[42,"rumble | train | locomotive | heavy | extraneous",36],[43,"pulsating | pulsation | barely | comming | earshurting",36],[44,"continue | painful | night | several | pitched",36],[45,"body | vibration | feels | physical | well",36],[46,"intermittent | humming | lowfrequency | hummingdeep | consecutive",35],[47,"whoom | motor | aconditioned | wahing | huum",34],[48,"pulsing | heartbeat | cleaning | stops | quickly",34],[49,"humrumble | humming | lowdeep | hummingrumble | fossilburning",34],[50,"dishwasher | pumping | humming | locked | restrained",33],[51,"pulses | breath | humming | yoga | cavity",33],[52,"rumble | diesel | shake | 247 | 80100",32],[53,"level | bumblebee | create | elephant | heavily",32],[54,"rumbling | occurs | under | ruled | usually",32],[55,"droning | directionless | somebody | grass | children",32],[56,"train | tracks | allmost | mile | far",32],[57,"plane | jet | planes | daughter | rumbling",30],[58,"throbbing | bones | 160 | spike | paced",30],[59,"generator | humming | transformer | palpating | generatorengine",30],[60 ...
